# %%
import logging

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(message)s",
    force=True
)

logger = logging.getLogger("SocialMediaPipeline")
logger.setLevel(logging.INFO)

print(logger)
# Out:
# <Logger SocialMediaPipeline (INFO)>
# 2026-07-11 11:22:48,862 | INFO | Closing down clientserver connection
# 2026-07-11 11:22:48,868 | INFO | Closing down clientserver connection
